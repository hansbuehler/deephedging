# %% [markdown]
# # Deep Hedging
# ## Testing the SimpleWorld_Spot_BS generator

# %%
""" Slighly annoying: by default the SageMaker Python import directory does not include our git directory """
import os
p = os.getcwd()
dhn = "/deephedging/"
i = p.find(dhn)
if i!=-1:
    p = p[:i]
    import sys
    sys.path.append(p)
    print("SageMaker: added python path %s" % p)
# Out:
# SageMaker: added python path /home/ec2-user/SageMaker

# %%
import numpy as np
from IPython.display import display, Markdown, Latex

from deephedging.world_bs import SimpleWorld_BS
from cdxbasics.config import Config  # pip install

# remove for production code. Keep while developping
import imp
import deephedging.world as _
imp.reload(_)

display(Markdown("## Simple Black & Scholes World"))
config = Config()
config.samples = 10000
config.drift = 0.15  # drift
        
world  = SimpleWorld_BS( config )
world.plot(plot_samples=10)
# Out:
# 2023-01-21 12:29:20.603553: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-21 12:29:20.810510: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Tensorflow version 2.10.0 running on 1 CPUs and 0 GPUs
# 2023-01-21 12:29:22.734458: E tensorflow/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-01-21 12:29:22.734501: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ip-172-16-12-144.eu-west-2.compute.internal): /proc/driver/nvidia/version does not exist
# /tmp/ipykernel_10092/2793648905.py:8: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp
# ## Simple Black & Scholes World
# 2023-01-21 12:29:23.495481: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Config settings:
# config['drift'] = 0.15
# config['samples'] = 10000
