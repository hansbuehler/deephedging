# %% [markdown]
# # Deep Hedging AI
# ### Convergence to Black & Scholes Delta
# #### Base case: BS with (statistical) drift 0.1, cvar@1, 400 epochs, zero cost, 50000 path
# #### This file: exp2 utility
#
# Hans Buehler, January 2nd, 2023

# %%
""" Slighly annoying: by default the SageMaker Python import directory does not include our git directory """
import os
p = os.getcwd()
dhn = "/deephedging/"
i = p.find(dhn)
if i!=-1:
    p = p[:i]
    import sys
    sys.path.append(p)
    print("SageMaker: added python path %s" % p)
# Out:
# SageMaker: added python path /home/ec2-user/SageMaker

# %%
print("Deep Hedging AI says hello  ... ", end='')
from cdxbasics.config import Config
from deephedging.trainer import train
from deephedging.gym import VanillaDeepHedgingGym
from deephedging.world import SimpleWorld_Spot_ATM
import numpy as np

from IPython.display import display, Markdown

# see print of the config below for numerous options
config = Config()
# world
config.world.samples = 50000
config.world.steps = 20
config.world.black_scholes = True
config.world.rvol = 0.2    # 20% volatility
config.world.drift = 0.   # real life drift
config.world.cost_s = 0.
# gym
config.gym.objective.utility = "exp2"
config.gym.objective.lmbda = 10.
config.gym.agent.network.depth = 5
config.gym.agent.network.width = 40
config.gym.agent.network.activation = "softplus"
# trainer
#config.trainer.train.optimizer = "adam"
config.trainer.train.batch_size = None
config.trainer.train.epochs = 400
config.trainer.visual.epoch_refresh = 1
config.trainer.visual.time_refresh = 10
config.trainer.visual.confidence_pcnt_lo = 0.25
config.trainer.visual.confidence_pcnt_hi = 0.75

display(Markdown("## Deep Hedging in a Black \& Scholes World"))

# create world & validation world
world  = SimpleWorld_Spot_ATM( config.world )
val_world  = world.clone(samples=config.world("samples")//10)

# create training environment
gym = VanillaDeepHedgingGym( config.gym )

# create training environment
train( gym=gym, world=world, val_world=val_world, config=config.trainer )
r = gym(world.tf_data)
print("Keys of the dictionary returned by the gym: ", r.keys())

print("=========================================")
print("Config usage report")
print("=========================================")
print( config.usage_report() )
config.done()
# Out:
# Deep Hedging AI says hello  ...
# 2023-01-08 10:52:10.505840: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-01-08 10:52:10.505899: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ip-172-16-57-75.us-east-2.compute.internal): /proc/driver/nvidia/version does not exist
# Tensorflow version 2.7.1 running on 1 CPUs and 0 GPUs
# ## Deep Hedging in a Black \& Scholes World
# 2023-01-08 10:52:11.388089: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-08 10:52:13.507675: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# Caching enabled @ '/home/ec2-user/dh_cache/18a66d7546b539afccd75c57004d9463.pck'
# Cache successfully loaded. Current epoch: 399
# Nothing to do: cached model loaded from /home/ec2-user/dh_cache/18a66d7546b539afccd75c57004d9463.pck represents a trained model up to 400 epochs (you have asked to train for 400 epochs).
# Raise number of epochs or turn off caching to re-start training.
#
# Plotting results for the trained model.
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_9918/1062043432.py in <cell line: 44>()
#      42
#      43 # create training environment
# ---> 44 train( gym=gym, world=world, val_world=val_world, config=config.trainer )
#      45 r = gym(world.tf_data)
#      46 print("Keys of the dictionary returned by the gym: ", r.keys())
#
# ~/SageMaker/deephedging/trainer.py in train(gym, world, val_world, config, verbose)
#     172             monitor.why_stopped = "Aborted"
#     173
# --> 174     monitor.finalize()
#     175
#     176
#
# ~/SageMaker/deephedging/plot_training.py in finalize(self)
#     701
#     702         # upgrade plot
# --> 703         self.plotter(self.data, self.world, self.val_world , last_cached_epoch = self.cache_last_epoch, cache_epoch_off = self.cache_epoch_off)
#     704         print("\n Status: %s.\n Weights set to best epoch: %ld\n%s" % (self.data.why_stopped, self.data.best_epoch,cached_msg) )
#     705         self.plotter.close()
#
# ~/SageMaker/deephedging/plot_training.py in __call__(self, monitor, world, val_world, last_cached_epoch, cache_epoch_off)
#     446         # in the event of being restored from caching, timing stats at 'cache_epoch_off'
#     447         total_time_passed = time.time() - monitor.time0
# --> 448         time_per_epoch    = total_time_passed / float(monitor.epoch+1-cache_epoch_off)
#     449         time_left         = time_per_epoch * float(monitor.epochs-monitor.epoch)
#     450         weights           = fmt_big_number( monitor.num_weights )
#
# ZeroDivisionError: float division by zero

# %%
import deephedging.plot_bs_hedge as plot_bs_hedge
import imp
imp.reload(plot_bs_hedge)

display(Markdown("## Hedging results in detail"))
plot_bs_hedge.plot_blackscholes( world, gym, config )
