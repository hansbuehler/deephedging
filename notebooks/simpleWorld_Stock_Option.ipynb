# %% [markdown]
# # Deep Hedging
# ## Testing the SimpleWorld_Stock_Option world generator

# %%
import numpy as np
import imp
import packages.cdxbasics.cdxbasics.config as _
imp.reload(_)
import packages.cdxbasics.cdxbasics.dynaplot as _
imp.reload(_)
import deephedging.world as _
imp.reload(_)

from deephedging.world import SimpleWorld_Stock_Option
from packages.cdxbasics.cdxbasics.config import Config

config = Config()
config.samples = 10000

world  = SimpleWorld_Stock_Option( config )
world.plot(plot_samples=10)
# Out:
# Config settings:
# config['samples'] = 10000
