# %% [markdown]
# ### Ray visual updates

# %%
from cdxbasics.config import Config
from cdxbasics.prettydict import PrettyOrderedDict as pdct
from cdxbasics.prettydict import PrettyOrderedDict 
import numpy as np
from cdxbasics.dynaplot import figure
from IPython.display import display, Markdown

import ray
ray.init(ignore_reinit_error=True)
# Out:
# 2023-02-06 07:06:55,540	INFO worker.py:1518 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.7.15', ray_version='2.0.1', ray_commit='{{RAY_COMMIT_SHA}}', address_info={'node_ip_address': '127.0.0.1', 'raylet_ip_address': '127.0.0.1', 'redis_address': None, 'object_store_address': 'tcp://127.0.0.1:55770', 'raylet_socket_name': 'tcp://127.0.0.1:62879', 'webui_url': '', 'session_dir': 'C:\\Users\\hansb\\AppData\\Local\\Temp\\ray\\session_2023-02-06_07-06-53_252583_40096', 'metrics_export_port': 58277, 'gcs_address': '127.0.0.1:54524', 'address': '127.0.0.1:54524', 'dashboard_agent_listen_port': 52365, 'node_id': 'db4d7efafa0e5e7c9b8851b654823fd7aecfa029e6989b4907c679f8'})

# %%
@ray.remote
class Visualizer(object):
    
    def __init__(self):
        self.workers = PrettyOrderedDict()
        pass
    
    def register(self, name):
        if name in self.workers:
            return self.workers[name]
        self.workers[name] = ""
        return 
    
@ray.remote    
class Worker(object):
    
    def __init__(self, name, visualizer):
        self.handle = visualizer.register(name)

    def write( self, text, *argc, **argv ):
        text = fmt(text,argc,argv)
        self.visualizer.write.remote(text)

# %%
import sys
#print("BEWARE: \x1b[1;33;41mugly colors\x1b[m!", file=sys.stderr)
print("AB\x1b[43mCD\x1b[35mEF\x1b[1mGH\x1b[4mIJ\x1b[7m"
      "KL\x1b[49mMN\x1b[39mOP\x1b[22mQR\x1b[24mST\x1b[27mUV")
# Out:
# ABCDEFGHIJKLMNOPQRSTUV

# %%
import os
os.system("")  # enables ansi escape characters in terminal

COLOR = {
    "HEADER": "\033[95m",
    "BLUE": "\033[94m",
    "GREEN": "\033[92m",
    "RED": "\033[91m",
    "ENDC": "\033[0m",
}

print(COLOR["GREEN"], "Testing Green!!", COLOR["ENDC"])
# Out:
#  Testing Green!!
